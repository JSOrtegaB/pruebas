# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("fa_ali.csv")

# %%
df.head()
# Out:
#    FOLIO_I    FOLIO_INT  id_alim  \
# 0  1001019  01001019_03        1
# 1  1001019  01001019_03        2
# 2  1001019  01001019_03        3
# 3  1001019  01001019_03        4
# 4  1001019  01001019_03        5
#
#                                             alimento          por_est  pa1  \
# 0                                      Leche Liconsa  1 vaso (240 ml)    9
# 1                                Otra leche opción A  1 vaso (240 ml)    7
# 2                                Otra leche opción B  1 vaso (240 ml)    9
# 3                                Otra leche opción C  1 vaso (240 ml)    9
# 4  Leche preparada de sabor (chocolate u otro sabor)  1 vaso (240 ml)    9
#
#   esp_alim pa2 pa3   pa4 maquina1  completa       ponde_f  estrato  est_sel  \
# 0                           MQ361         1  34505.129532        3       13
# 1     7000   2   E  1.00    MQ361         1  34505.129532        3       13
# 2                           MQ361         1  34505.129532        3       13
# 3                           MQ361         1  34505.129532        3       13
# 4                           MQ361         1  34505.129532        3       13
#
#              upm  region  x_region
# 0  0100100010341       4         5
# 1  0100100010341       4         5
# 2  0100100010341       4         5
# 3  0100100010341       4         5
# 4  0100100010341       4         5

# %%
df["alimento"].unique()
# Out:
# array(['Leche Liconsa', 'Otra leche opción A', 'Otra leche opción B',
#        'Otra leche opción C',
#        'Leche preparada de sabor (chocolate u otro sabor)',
#        'Agregado a la leche: Azúcar',
#        'Agregado a la leche: Chocolate u otro saborizante',
#        'Queso panela o fresco o cottage',
#        'Quesos madurados (chihuahua, manchego, gouda, etc.)',
#        'Yogur de vaso: a) Entero natural',
#        'Yogur de vaso: b) Entero con frutas',
#        'Yogur de vaso: c) Bajo en grasa o light natural o con fruta (vitalinea, alpura light, lala light, etc.)',
#        'Yogur para beber: a) Entero natural',
#        'Yogur para beber: b) Entero con fruta',
#        'Yogur para beber: c) Bajo en grasa o light natural o con fruta (vitalinea, activia 0%, Siluette)',
#        'Danonino o similar', 'Yakult o similares', 'Plátano',
#        'Plátano frito', 'Jícama', 'Naranja o mandarina', 'Manzana o pera',
#        'Melón o sandía', 'Guayaba', 'Mango', 'Papaya', 'Piña', 'Toronja',
#        'Fresa', 'Uvas', 'Durazno/melocotón', 'Frutas en almíbar',
#        'Frutas cristalizadas o secas', 'Tortitas de verduras capeadas',
#        'Jitomate', 'Hojas Verdes (acelgas, espinacas, quelites)',
#        'Chayote', 'Zanahoria', 'Calabacita', 'Brócoli o coliflor', 'Col',
#        'Ejotes', 'Elote', 'Lechuga', 'Nopales', 'Pepino', 'Aguacate',
#        'Chile poblano',
#        'Cebolla por ejemplo en ensaladas, antojitos, o comida rápida',
#        'Verduras envasadas como chícharo, zanahoria, champiñones y ejotes.',
#        'Verduras congeladas como chícharo, zanahoria, brócoli, coliflor, ejotes',
#        'Torta o sándwich con pan blanco',
#        'Torta o sándwich con pan integral', 'Hamburguesa', 'Pizza',
#        'Hot dog', 'Carne de puerco', 'Carne de res',
#        'Carne de res seca (machaca)', 'Longaniza o chorizo',
#        'Salchicha de puerco, pavo o combinado, jamón de puerco o pavo o mortadela (a parte de en torta, sándwich o hot dog)',
#        'Pollo a) Pierna, muslo o pechuga', 'Pollo b) Ala, patas',
#        'Pollo c) Higadito o molleja', 'Huevo a) Tibio o cocido',
#        'Huevo b) Frito, estrellado o revuelto', 'Pescado fresco',
#        'Pescado seco (charalitos, bacalao)',
#        'Atún y sardina (en tomate, agua o aceite)',
#        'Algún marisco (camarón, ostiones, etc.)',
#        'Frijoles preparados en casa: a) De la olla',
#        'Frijoles preparados en casa: b) Refritos',
#        'Frijoles envasados o de lata: a) De la olla',
#        'Frijoles envasados o de lata: b) Refritos',
#        'Lenteja, garbanzo, haba amarilla o alubia', 'Arroz guisado',
#        'Avena en hojuelas, amaranto natural o tostado', 'Pan blanco',
#        'Pan integral', 'Pan dulce (excepto donas y churros)',
#        'Donas y churros de panadería', 'Galletas integrales',
#        'Galletas saladas', 'Papas a) Cocida',
#        'Papas b) Frita o tortita de papa',
#        'Cereal a) Chocolate (Chocozucaritas, chocokrispis)',
#        'Cereal b) Light/cuidado de la figura (Special K)',
#        'Cereal c) Hojuela endulzada (Zucaritas)',
#        'Cereal d) Básico (Corn Flakes, arroz inflado sin sabor)',
#        'Cereal e) Variedades (Apple jacks, honey smacks, corn pops)',
#        'Cereal f) Sabor a frutas (Froot loops)',
#        'Cereal g) Fibra (All Bran)', 'Cereal h) Especialidades (Crusli)',
#        'Cereal i) Multi ingredientes (Extra)',
#        'Antojitos con vegetales como sopes, quesadillas, tlacoyos, gorditas, y enchiladas (NO TACOS): a) Sin freír',
#        'Antojitos con vegetales como sopes, quesadillas, tlacoyos, gorditas, y enchiladas (NO TACOS): b) Fritos',
#        'Antojitos con res, cerdo pollo, vísceras, etc como tacos, quesadillas, tlacoyos, enchiladas, gorditas: a) Sin freír',
#        'Antojitos con res, cerdo pollo, vísceras, etc como tacos, quesadillas, tlacoyos, enchiladas, gorditas: b) Fritos',
#        'Pozole (todos tipos)', 'Tamal (todos tipos)',
#        'Atole de maíz a) Atole con agua o pozol',
#        'Atole de maíz b) Atole con leche (aparte de la reportada en el apartado de “Productos lácteos”)',
#        'Refresco Normal', 'Refresco Dieta', 'Café: a) Café sin azúcar',
#        'Café: b) Azúcar agregada al café',
#        'Café: c) Leche agregada al café (aparte de la reportada en el apartado de “Productos lácteos”)',
#        'Café: d) Sustituto de crema agregada al café',
#        'Té o infusión: a) Té sin azúcar',
#        'Té o infusión: b) Azúcar agregada al té',
#        'Jugos naturales sin azúcar', 'Jugos naturales con azúcar',
#        'Aguas de fruta natural con azúcar',
#        'Aguas de fruta natural sin azúcar',
#        'Bebidas o aguas de sabor industrializadas sin azúcar (incluyendo dietéticas como Clight, Be-light, etc.)',
#        'Bebidas o aguas de sabor industrializadas con azúcar (frutsi, bonafina.)',
#        'Néctares de frutas o pulpa de frutas industrializados con azúcar (boing, jumex)',
#        'Agua sola', 'Bebidas alcohólicas', 'Chocolate',
#        'Dulce (caramelos, paletas)',
#        'Dulces enchilados (miguelitos, tamarindos)',
#        'Frituras (todos tipos, incluyendo cacahuates japoneses)',
#        'Paletas y dulces de malvavisco (paleta payaso, bubu-lu-bu)',
#        'Gelatina, flan', 'Pastel o pay',
#        'Helado, nieves y paletas de agua', 'Helado y paletas de leche',
#        'Haba, \xa0garbanzo o lentejas como botana',
#        'Nuez, almendra, avellana, cacahuates, semilla de calabaza (pepita) o de girasol, pistache, piñón, etc.',
#        'Palomitas de maíz caseras, de microondas o del cine (Todos tipos, excepto acarameladas)',
#        'Pastelillos y donas industrializadas',
#        'Galletas dulces (todos tipos)', 'Barras de cereal',
#        'Caldo de pollo, res o verduras (sólo caldo)',
#        'Sopa o caldo con verduras', 'Sopa de pasta a) Sopa caldosa',
#        'Sopa de pasta b) Sopa seca', 'Crema de verduras',
#        'Sopas instantáneas',
#        'Limón por ejemplo en ensaladas, caldos, o carnes',
#        'Cebolla por ejemplo en salsas, o caldillos (molida o entera)',
#        'Chiles frescos por ejemplo en salsas, tacos, guisados (molido o entero)',
#        'Chiles envasados o enlatados, por ejemplo en el sándwich, torta, guisados.',
#        'Chile seco por ejemplo en salsas, tacos, guisados (molido o entero)',
#        'Tomate verde y jitomate por ejemplo en salsas, tacos, o guisados (molido o entero)',
#        'Azúcar (a parte de la agregada a las bebidas, leche, té, café, agua de frutas) por ejemplo en fresas o plátanos con crema',
#        'Margarina', 'Mantequilla', 'Mayonesa', 'Crema', 'Manteca vegetal',
#        'Manteca animal (cerdo o pollo)',
#        'Sal o condimento con sal agregada a sus alimentos',
#        'Salsas y aderezos agregados a sus alimentos: a) Cátsup',
#        'Salsas y aderezos agregados a sus alimentos: b) Salsa picante para botana agregada a sus alimentos',
#        'Salsas y aderezos agregados a sus alimentos: c) Salsa de soya, salsa inglesa o sazonadores líquidos agregados a sus alimentos'],
#       dtype=object)

# %%
df["alimento"].value_counts(ascending=True)
# Out:
# Leche Liconsa                                                                                                                    3248
# Atole de maíz a) Atole con agua o pozol                                                                                          3248
# Atole de maíz b) Atole con leche (aparte de la reportada en el apartado de “Productos lácteos”)                                  3248
# Refresco Normal                                                                                                                  3248
# Refresco Dieta                                                                                                                   3248
#                                                                                                                                  ...
# Hamburguesa                                                                                                                      3248
# Pizza                                                                                                                            3248
# Hot dog                                                                                                                          3248
# Cebolla por ejemplo en ensaladas, antojitos, o comida rápida                                                                     3248
# Salsas y aderezos agregados a sus alimentos: c) Salsa de soya, salsa inglesa o sazonadores líquidos agregados a sus alimentos    3248
# Name: alimento, Length: 157, dtype: int64

# %%
import mysql.connector as msql

# %%
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost', user='sortega',  
                        password='nofear')#give ur username, password
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
except Error as e:
    print("Error while connecting to MySQL", e)
